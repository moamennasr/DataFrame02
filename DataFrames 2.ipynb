# %%
import pandas as pd

# %%
df = pd.read_csv("employees.csv")
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df["Start Date"] = pd.to_datetime(df["Start Date"])
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1     Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2      Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3      Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4      Larry    Male 1998-01-24         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df["Last Login Time"] = pd.to_datetime(df["Last Login Time"])
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-02-24 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-02-24 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-02-24 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-02-24 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-02-24 16:47:00  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df["Senior Management"] = df["Senior Management"].astype("bool")
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-02-24 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-02-24 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-02-24 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-02-24 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-02-24 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df["Gender"] = df["Gender"].astype("category")
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-02-24 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-02-24 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-02-24 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-02-24 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-02-24 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.1+ KB

# %%
df = pd.read_csv("employees.csv", parse_dates= ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-02-24 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-02-24 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-02-24 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-02-24 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-02-24 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %% [markdown]
# # filter DF based on a condition

# %%
df = pd.read_csv("employees.csv", parse_dates= ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-02-24 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-02-24 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-02-24 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-02-24 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-02-24 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df[df["Gender"] == "Male"]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2022-02-24 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2022-02-24 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2022-02-24 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2022-02-24 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2022-02-24 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2022-02-24 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2022-02-24 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2022-02-24 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2022-02-24 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2022-02-24 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
df[df["Team"] == "Finance"] # or
mask = df["Team"] == "Finance"
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-02-24 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-02-24 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2022-02-24 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2022-02-24 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2022-02-24 22:47:00  114796    6.796
# ..         ...     ...        ...                 ...     ...      ...
# 907  Elizabeth  Female 1998-07-27 2022-02-24 11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19 2022-02-24 16:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08 2022-02-24 05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16 2022-02-24 08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31 2022-02-24 06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# ...

# %%
df[df["Senior Management"]]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-02-24 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-02-24 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2022-02-24 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-02-24 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2022-02-24 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 991       Rose  Female 2002-08-25 2022-02-24 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2022-02-24 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2022-02-24 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2022-02-24 17:47:00   98874    4.479
# 999     Albert    Male 2012-05-15 2022-02-24 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
df[df["Team"] != "Marketing"]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2022-02-24 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-02-24 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-02-24 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-02-24 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2022-02-24 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2022-02-24 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2022-02-24 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-02-24 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-02-24 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-02-24 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 1                 True                   NaN
# ...

# %%
df[df["Salary"] > 110000] # df[] return true
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-02-24 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022
Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-02-24 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-02-24 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-02-24 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-02-24 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-02-24 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
mask1 = df["Senior Management"]
mask2 = df["Start Date"] < "1990-01-01"
df[mask1 | mask2] #or --> [|]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-02-24 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-02-24 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2022-02-24 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-02-24 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2022-02-24 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 992    Anthony    Male 2011-10-16 2022-02-24 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2022-02-24 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2022-02-24 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2022-02-24 06:30:00   42392   19.675
# 999     Albert    Male 2012-05-15 2022-02-24 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
# if we have three coditions which the first two are a must but not the third
# df[(mask1 & mask2) | mask3]

# %% [markdown]
# # .isin() method

# %%
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-02-24 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-02-24 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-02-24 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-02-24 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-02-24 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
mask = df["Team"].isin(["Legal", "Sales", "Product"]) # comparing values to a series
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2022-02-24 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2022-02-24 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2022-02-24 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2022-02-24 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2022-02-24 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2022-02-24 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2022-02-24 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2022-02-24 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2022-02-24 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2022-02-24 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# ...

# %% [markdown]
# # The .isnull() & .notnull() methods

# %%
df = pd.read_csv("employees.csv", parse_dates= ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-02-25 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-02-25 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-02-25 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-02-25 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-02-25 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df[df["Team"].isnull()]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2022-02-25 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2022-02-25 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2022-02-25 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2022-02-25 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2022-02-25 23:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 2022-02-25 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 2022-02-25 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 2022-02-25 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 2022-02-25 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 2022-02-25 18:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 2022-02-25 17:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 2022-02-25 06:06:00   66067   10.957
# ...

# %%
df["Gender"].notnull()
df[df["Gender"].notnull()]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2022-02-25 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2022-02-25 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2022-02-25 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2022-02-25 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2022-02-25 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2022-02-25 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2022-02-25 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2022-02-25 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2022-02-25 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2022-02-25 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %% [markdown]
# # The .between() Method

# %%
df = pd.read_csv("employees.csv", parse_dates= ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2022-02-25 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2022-02-25 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2022-02-25 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2022-02-25 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2022-02-25 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
df[df["Salary"].between(6000, 70000)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2022-02-25 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 2022-02-25 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2022-02-25 10:43:00   45906   11.598
# 10      Louise  Female 1980-08-12 2022-02-25 09:01:00   63241   15.132
# 14    Kimberly  Female 1999-01-14 2022-02-25 07:13:00   41426   14.543
# ..         ...     ...        ...                 ...     ...      ...
# 988      Alice  Female 2004-10-05 2022-02-25 09:34:00   47638   11.209
# 989     Justin     NaN 1991-02-10 2022-02-25 16:58:00   38344    3.794
# 993       Tina  Female 1997-05-15 2022-02-25 15:53:00   56450   19.040
# 996    Phillip    Male 1984-01-31 2022-02-25 06:30:00   42392   19.675
# 998      Larry    Male 2013-04-20 2022-02-25 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 1                 True                   NaN
# ...

# %%
df[df["Bonus %"].between(2.0, 5.0)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2022-02-25 06:53:00   61933    4.170
# 20        Lois     NaN 1995-04-22 2022-02-25 19:18:00   64714    4.934
# 40     Michael    Male 2008-10-10 2022-02-25 11:25:00   99283    2.665
# 49       Chris     NaN 1980-01-24 2022-02-25 12:13:00  113590    3.055
# 60       Paula     NaN 2005-11-23 2022-02-25 14:01:00   48866    4.271
# ..         ...     ...        ...                 ...     ...      ...
# 943      Wayne    Male 2006-09-08 2022-02-25 11:09:00   67471    2.728
# 961    Antonio     NaN 1989-06-18 2022-02-25 21:37:00  103050    3.050
# 976     Denise  Female 1992-10-19 2022-02-25 05:42:00  137954    4.195
# 989     Justin     NaN 1991-02-10 2022-02-25 16:58:00   38344    3.794
# 994     George    Male 2013-06-21 2022-02-25 17:47:00   98874    4.479
#
#      Senior Management          Team
# 1                 True           NaN
# 20                True         Legal
# ...

# %%
df[df["Last Login Time"].between("08:30AM", "12:00PM")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2022-02-25 11:17:00  130590   11.858
# 7          NaN  Female 2015-07-20 2022-02-25 10:43:00   45906   11.598
# 10      Louise  Female 1980-08-12 2022-02-25 09:01:00   63241   15.132
# 18       Diana  Female 1981-10-23 2022-02-25 10:27:00  132940   19.082
# 33        Jean  Female 1993-12-18 2022-02-25 09:07:00  119082   16.180
# ..         ...     ...        ...                 ...     ...      ...
# 963        Ann  Female 1994-09-23 2022-02-25 11:15:00   89443   17.940
# 977      Sarah  Female 1995-12-04 2022-02-25 09:16:00  124566    5.949
# 982       Rose  Female 1982-04-06 2022-02-25 10:43:00   91411    8.639
# 988      Alice  Female 2004-10-05 2022-02-25 09:34:00   47638   11.209
# 992    Anthony    Male 2011-10-16 2022-02-25 08:35:00  112769   11.625
#
#      Senior Management                  Team
# 2                False               Finance
# ...

# %% [markdown]
# # the .duplicated() method

# %%
df = pd.read_csv("employees.csv", parse_dates= ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.sort_values("First Name", inplace=True)
df.head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-02-25 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2022-02-25 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2022-02-25 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2022-02-25 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2022-02-25 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution

# %%
mask = ~df["First Name"].duplicated(keep= False)
df[mask] # names that mentioned once
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2022-02-25 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2022-02-25 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2022-02-25 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2022-02-25 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2022-02-25 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2022-02-25 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2022-02-25 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2022-02-25 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2022-02-25 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# ...

# %% [markdown]
# # delete duplicates with .drop_duplicates() method

# %%
df = pd.read_csv("employees.csv", parse_dates= ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.sort_values("First Name", inplace=True)
df.head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-02-26 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2022-02-26 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2022-02-26 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2022-02-26 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2022-02-26 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution

# %%
len(df)
# Out:
# 1000

# %%
df.drop_duplicates(subset= ["First Name"])
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-02-26 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2022-02-26 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2022-02-26 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2022-02-26 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2022-02-26 09:34:00   47638   11.209
# ..         ...     ...        ...                 ...     ...      ...
# 433      Wanda  Female 2008-07-20 2022-02-26 13:44:00   65362    7.132
# 177      Wayne    Male 2012-04-07 2022-02-26 08:00:00  102652   14.085
# 820    William    Male 1993-11-18 2022-02-26 12:27:00   54058    5.182
# 450     Willie    Male 2009-08-22 2022-02-26 13:03:00   55038   19.691
# 7          NaN  Female 2015-07-20 2022-02-26 10:43:00   45906   11.598
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %%
df.drop_duplicates(subset= ["First Name", "Team"])
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-02-26 10:20:00   61602   11.849
# 440      Aaron    Male 1990-07-22 2022-02-26 14:53:00   52119   11.343
# 137       Adam    Male 2011-05-21 2022-02-26 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2022-02-26 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2022-02-26 11:59:00   71276    5.027
# ..         ...     ...        ...                 ...     ...      ...
# 149        NaN  Female 2014-08-17 2022-02-26 14:00:00   86230    8.578
# 157        NaN  Female 2005-07-27 2022-02-26 08:32:00   79536   14.443
# 269        NaN  Female 1992-08-02 2022-02-26 20:35:00  145316   18.517
# 329        NaN    Male 2010-01-27 2022-02-26 02:57:00   87760   14.987
# 481        NaN  Female 2013-04-27 2022-02-26 06:40:00   93847    1.085
#
#      Senior Management                  Team
# 101               True             Marketing
# ...

# %% [markdown]
# # the .unique() & .nunique() Methods

# %%
df = pd.read_csv("employees.csv", parse_dates= ["Start Date", "Last Login Time"])
df["Senior Management"] = df["Senior Management"].astype("bool")
df["Gender"] = df["Gender"].astype("category")
df.sort_values("First Name", inplace=True)
df.head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2022-02-26 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2022-02-26 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2022-02-26 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2022-02-26 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2022-02-26 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution

# %%
df["Gender"].unique()
# Out:
# ['Male', NaN, 'Female']
# Categories (2, object): ['Female', 'Male']

# %%
df["Team"].unique()
# Out:
# array(['Marketing', 'Client Services', 'Distribution', 'Product',
#        'Human Resources', 'Engineering', 'Finance',
#        'Business Development', 'Sales', nan, 'Legal'], dtype=object)

# %%
df["Team"].nunique() # number of unique values -- NAN not incloded
# Out:
# 10

# %%
df["Team"].nunique(dropna= False) # number of unique values -- NAN  incloded
# Out:
# 11
